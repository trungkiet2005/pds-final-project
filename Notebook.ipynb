# %% [markdown]
# # **Data Science Final Project**
#
# **Student Information:**
#
# | StudentID | Full Name |
# |-----------|-----------|
# | [ID] | [Your Name] |
# | [ID] | [Your Name] |
# | [ID] | [Your Name] |

# %% [markdown]
# ## **Table of Contents**
#
# 1. [Collecting Data](#collect)
#    - [a. About the Dataset](#about)
#    - [b. License and Copyright](#license)
#    - [c. Data Collection Method](#howtocollect)
# 2. [Exploratory Data Analysis (EDA)](#eda)
#    - [a. Overall Data View](#overall)
#    - [b. Row Details](#row)
#    - [c. Column Details](#column)
#    - [d. Value Distributions](#distribution)
# 3. [Asking Meaningful Questions](#ask)
#    - [a. Question 1](#question1)
#    - [b. Question 2](#question2)
#    - [c. Question 3](#question3)
# 4. [Data Preprocessing & Analysis](#pre-and-anal)
#    - [a. Answering Question 1](#answer1)
#    - [b. Answering Question 2](#answer2)
#    - [c. Answering Question 3](#answer3)
# 5. [Reflection](#reflection)
# 6. [References](#references)

# %% [markdown]
# ## **1. Collecting Data** <a name="collect"></a>
#
# ### **a. About the Dataset** <a name="about"></a>
#
# [Describe the dataset here. What is its subject? Why is it important? What is its source (e.g., Kaggle, UCI Repository)? Provide a link if available.]

# %% [markdown]
# ### **b. License and Copyright** <a name="license"></a>
#
# [Provide information about the dataset's license (e.g., CC0, ODbL). Do the creators allow for this type of use? Who are the original authors or donors?]

# %% [markdown]
# ### **c. Data Collection Method** <a name="howtocollect"></a>
#
# [Describe how the data was collected by the original authors.]

# %% [markdown]
# ## **2. Exploratory Data Analysis (EDA)** <a name="eda"></a>

# %% [markdown]
# **Import necessary libraries**

# %% [markdown]
# ### **a. Overall Data View** <a name="overall"></a>

# %% [markdown]
# **Read the data** <br>
# **Data shape**

# %% [markdown]
# ### **b. Row Details** <a name="row"></a>

# %% [markdown]
# **Meaning of each row**
#
# [Explain what each row in the dataset represents. For example: "Each row represents a single patient's record."]

# %% [markdown]
# ### **c. Column Details** <a name="column"></a>

# %% [markdown]
# ### **d. Value Distributions** <a name="distribution"></a>

# %% [markdown]
# ## **3. Asking Meaningful Questions** <a name="ask"></a>
#
# ### **a. Question 1** <a name="question1"></a>
#
# **Question:** [State your first question here. e.g."]
#
# **Benefits:** [Explain why answering this question is valuable. e.g.]

# %% [markdown]
# ### **b. Question 2** <a name="question2"></a>
#
# **Question:** [State your second question here. e.g."]
#
# **Benefits:** [Explain why answering this question is valuable. e.g.]

# %% [markdown]
# ### **b. Question 3** <a name="question3"></a>
#
# **Question:** [State your third question here. e.g."]
#
# **Benefits:** [Explain why answering this question is valuable. e.g.]

# %% [markdown]
# ## **4. Data Preprocessing & Analysis** <a name="pre-and-anal"></a>
#
# ### **a. Answering Question 1** <a name="answer1"></a>

# %% [markdown]
# ### **b. Answering Question 2** <a name="answer2"></a>

# %% [markdown]
# ### **c. Answering Question 3** <a name="answer3"></a>

# %% [markdown]
# ## **5. Reflection** <a name="reflection"></a>
#
# ### **a. What difficulties did you encounter?**
# - **[Member 1 Name]:** [Describe difficulties]
# - **[Member 2 Name]:** [Describe difficulties]
# - **[Member 3 Name]:** [Describe difficulties]
# -
# ### **b. What have you learned?**
# - **[Member 1 Name]:** [Describe what you learned]
# - **[Member 2 Name]:** [Describe what you learned]
# - **[Member 3 Name]:** [Describe what you learned]
#
# ### **c. If you had more time, what would you do?**
# [Describe potential future work or improvements for the project.]

# %% [markdown]
# ## **6. References** <a name="references"></a>
#
# - [Link to dataset]
# - [Link to relevant articles or documentation]
# - ...
